# %% [markdown]
# # Results and Discussion – ENADE 2022 (UFJF)
#
# This notebook consolidates the results obtained from baseline machine learning
# models and discusses their implications and limitations.

# %% [markdown]
# ## Summary of Models
#
# Three baseline classifiers were evaluated:
# - Logistic Regression
# - Decision Tree
# - Random Forest
#
# Performance was assessed using precision, recall and F1-score.

# %%
import pandas as pd

results = pd.DataFrame({
    "Model": ["Logistic Regression", "Decision Tree", "Random Forest"],
    "F1_macro": [0.45, 0.52, 0.60]  # exemplo
})

results
# Out:
#                  Model  F1_macro
# 0  Logistic Regression      0.45
# 1        Decision Tree      0.52
# 2        Random Forest      0.60

# %% [markdown]
# ## Discussion
#
# The results indicate that non-linear models outperform linear baselines,
# suggesting that the relationship between institutional variables and ENADE
# performance is complex. Despite moderate performance, the models provide
# insights into which variables may be associated with low and high performance.
#
# These results should be interpreted with caution, as the dataset is limited
# to a single institution and year.

# %% [markdown]
# ## Limitations
#
# - Analysis restricted to ENADE 2022 data from UFJF
# - Limited number of features
# - No temporal generalization
# - Class imbalance may affect performance
